# %% [markdown]
# ## CS-5891-01 Special Topics Deep Learning
# ## Ronald Picard

# %% [markdown]
# Arch: 54-120-7
# Epochs: 10000
# Minibatch Size: 512
# Dropout: 0.25 For Each Hidden Layer
# Adam: lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False

# %%
#import sys
#print(sys.path)
#print(sys.executable)

import cnn_utils
from matplotlib import pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
import numpy
import keras.callbacks as cb

# fix random seed for reproducibility
numpy.random.seed(0)

def sortData(dataSet):
    
    typecover1_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 1)]
    typecover2_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 2)]
    typecover3_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 3)]
    typecover4_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 4)]
    typecover5_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 5)]
    typecover6_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 6)]
    typecover7_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 7)]
    
    return [typecover1_dataSet, typecover2_dataSet, typecover3_dataSet, typecover4_dataSet, typecover5_dataSet, typecover6_dataSet, typecover7_dataSet]

def getNbrTestingIndexes(nbr_testing_samples):
    
    percentSamplesFromTypeCover1 = 0.364605
    percentSamplesFromTypeCover2 = 0.487599
    percentSamplesFromTypeCover3 = 0.061537
    percentSamplesFromTypeCover4 = 0.004728
    percentSamplesFromTypeCover5 = 0.016339
    percentSamplesFromTypeCover6 = 0.029891
    percentSamplesFromTypeCover7 = 0.0353
    nbrIdxsFromTypeCover1 = numpy.floor(percentSamplesFromTypeCover1*nbr_testing_samples)
    nbrIdxsFromTypeCover2 = numpy.floor(percentSamplesFromTypeCover2*nbr_testing_samples)
    nbrIdxsFromTypeCover3 = numpy.floor(percentSamplesFromTypeCover3*nbr_testing_samples)
    nbrIdxsFromTypeCover4 = numpy.floor(percentSamplesFromTypeCover4*nbr_testing_samples)
    nbrIdxsFromTypeCover5 = numpy.floor(percentSamplesFromTypeCover5*nbr_testing_samples)
    nbrIdxsFromTypeCover6 = numpy.floor(percentSamplesFromTypeCover6*nbr_testing_samples)
    nbrIdxsFromTypeCover7 = numpy.floor(percentSamplesFromTypeCover7*nbr_testing_samples)
    total = nbrIdxsFromTypeCover1+nbrIdxsFromTypeCover2+nbrIdxsFromTypeCover3+nbrIdxsFromTypeCover4+nbrIdxsFromTypeCover5+nbrIdxsFromTypeCover6+nbrIdxsFromTypeCover7
    
    while(total < nbr_testing_samples):
        num = numpy.random.randint(1,7)
        if(num == 1):
            nbrIdxsFromTypeCover1 = nbrIdxsFromTypeCover1 + 1
        elif(num == 2):
            nbrIdxsFromTypeCover2 = nbrIdxsFromTypeCover2 + 1
        elif(num == 3):
            nbrIdxsFromTypeCover3 = nbrIdxsFromTypeCover3 + 1
        elif(num == 4):
            nbrIdxsFromTypeCover4 = nbrIdxsFromTypeCover4 + 1
        elif(num == 5):
            nbrIdxsFromTypeCover5 = nbrIdxsFromTypeCover5 + 1
        elif(num == 6):
            nbrIdxsFromTypeCover6 = nbrIdxsFromTypeCover6 + 1
        elif(num == 7):
            nbrIdxsFromTypeCover7 = nbrIdxsFromTypeCover7 + 1
        total = total + 1

    return [nbrIdxsFromTypeCover1, nbrIdxsFromTypeCover2, nbrIdxsFromTypeCover3, nbrIdxsFromTypeCover4, nbrIdxsFromTypeCover5, nbrIdxsFromTypeCover6, nbrIdxsFromTypeCover7]
    

def getNbrTrainingIndexes(nbr_training_samples):
    
    nbrIdxsFromTypeCover1 = nbr_training_samples/7
    nbrIdxsFromTypeCover2 = nbr_training_samples/7
    nbrIdxsFromTypeCover3 = nbr_training_samples/7
    nbrIdxsFromTypeCover4 = nbr_training_samples/7
    nbrIdxsFromTypeCover5 = nbr_training_samples/7
    nbrIdxsFromTypeCover6 = nbr_training_samples/7
    nbrIdxsFromTypeCover7 = nbr_training_samples/7
    total = nbrIdxsFromTypeCover1+nbrIdxsFromTypeCover2+nbrIdxsFromTypeCover3+nbrIdxsFromTypeCover4+nbrIdxsFromTypeCover5+nbrIdxsFromTypeCover6+nbrIdxsFromTypeCover7
    
    while(total < nbr_training_samples):
        num = numpy.random.randint(1,7)
        if(num == 1):
            nbrIdxsFromTypeCover1 = nbrIdxsFromTypeCover1 + 1
        elif(num == 2):
            nbrIdxsFromTypeCover2 = nbrIdxsFromTypeCover2 + 1
        elif(num == 3):
            nbrIdxsFromTypeCover3 = nbrIdxsFromTypeCover3 + 1
        elif(num == 4):
            nbrIdxsFromTypeCover4 = nbrIdxsFromTypeCover4 + 1
        elif(num == 5):
            nbrIdxsFromTypeCover5 = nbrIdxsFromTypeCover5 + 1
        elif(num == 6):
            nbrIdxsFromTypeCover6 = nbrIdxsFromTypeCover6 + 1
        elif(num == 7):
            nbrIdxsFromTypeCover7 = nbrIdxsFromTypeCover7 + 1
        total = total + 1

    return [nbrIdxsFromTypeCover1, nbrIdxsFromTypeCover2, nbrIdxsFromTypeCover3, nbrIdxsFromTypeCover4, nbrIdxsFromTypeCover5, nbrIdxsFromTypeCover6, nbrIdxsFromTypeCover7]
    
def getTrainingSet(dataSet, nbr_training_samples):
    
    [nbrIdxsFrmTypeCover1, nbrIdxsFrmTypeCover2, nbrIdxsFrmTypeCover3, nbrIdxsFrmTypeCover4, nbrIdxsFrmTypeCover5, nbrIdxsFrmTypeCover6, nbrIdxsFrmTypeCover7] = getNbrTrainingIndexes(nbr_training_samples)
    [typecover1_dataSet, typecover2_dataSet, typecover3_dataSet, typecover4_dataSet, typecover5_dataSet, typecover6_dataSet, typecover7_dataSet] = sortData(dataSet)
    
    indexesTypeCover1Array = []
    indexesTypeCover2Array = []
    indexesTypeCover3Array = []
    indexesTypeCover4Array = []
    indexesTypeCover5Array = []
    indexesTypeCover6Array = []
    indexesTypeCover7Array = []
    
    for i in range(0, nbr_training_samples-1):
        if(nbrIdxsFrmTypeCover1-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            while(idx in indexesTypeCover1Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            indexesTypeCover1Array.append(idx)
        if(nbrIdxsFrmTypeCover2-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            while(idx in indexesTypeCover2Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover2)
            indexesTypeCover2Array.append(idx)
        if(nbrIdxsFrmTypeCover3-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover3)
            while(idx in indexesTypeCover3Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover3)
            indexesTypeCover3Array.append(idx)
        if(nbrIdxsFrmTypeCover4-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover4)
            while(idx in indexesTypeCover4Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover4)
            indexesTypeCover4Array.append(idx)  
        if(nbrIdxsFrmTypeCover5-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover5)
            while(idx in indexesTypeCover5Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover5)
            indexesTypeCover5Array.append(idx) 
        if(nbrIdxsFrmTypeCover6-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover6)
            while(idx in indexesTypeCover6Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover6)
            indexesTypeCover6Array.append(idx)  
        if(nbrIdxsFrmTypeCover7-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover7)
            while(idx in indexesTypeCover7Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover7)
            indexesTypeCover7Array.append(idx)
    
    X_train_TypeCover1 = numpy.array(typecover1_dataSet)[indexesTypeCover1Array,0:53]
    X_train_TypeCover2 = numpy.array(typecover2_dataSet)[indexesTypeCover2Array,0:53]
    X_train_TypeCover3 = numpy.array(typecover3_dataSet)[indexesTypeCover3Array,0:53]
    X_train_TypeCover4 = numpy.array(typecover4_dataSet)[indexesTypeCover4Array,0:53]
    X_train_TypeCover5 = numpy.array(typecover5_dataSet)[indexesTypeCover5Array,0:53]
    X_train_TypeCover6 = numpy.array(typecover6_dataSet)[indexesTypeCover6Array,0:53]
    X_train_TypeCover7 = numpy.array(typecover7_dataSet)[indexesTypeCover7Array,0:53]

    Y_test_TypeCover1 = numpy.array(typecover1_dataSet)[indexesTypeCover1Array,55:61]
    Y_test_TypeCover2 = numpy.array(typecover2_dataSet)[indexesTypeCover2Array,55:61]
    Y_test_TypeCover3 = numpy.array(typecover3_dataSet)[indexesTypeCover3Array,55:61]
    Y_test_TypeCover4 = numpy.array(typecover4_dataSet)[indexesTypeCover5Array,55:61]
    Y_test_TypeCover5 = numpy.array(typecover5_dataSet)[indexesTypeCover5Array,55:61]
    Y_test_TypeCover6 = numpy.array(typecover6_dataSet)[indexesTypeCover6Array,55:61]
    Y_test_TypeCover7 = numpy.array(typecover7_dataSet)[indexesTypeCover7Array,55:61]
    Y_train = numpy.concatenate((Y_test_TypeCover1, Y_test_TypeCover2, Y_test_TypeCover3, Y_test_TypeCover4, Y_test_TypeCover5, Y_test_TypeCover6, Y_test_TypeCover7), axis=0)
    indexes = [indexesTypeCover1Array, indexesTypeCover2Array, indexesTypeCover3Array, indexesTypeCover4Array, indexesTypeCover5Array, indexesTypeCover6Array, indexesTypeCover7Array]
    
    return [X_train, Y_train, indexes]


def getTestSet(dataSet, training_indexes, nbr_testing_samples, use_all):
    
    [nbrIdxsFrmTypeCover1, nbrIdxsFrmTypeCover2, nbrIdxsFrmTypeCover3, nbrIdxsFrmTypeCover4, nbrIdxsFrmTypeCover5, nbrIdxsFrmTypeCover6, nbrIdxsFrmTypeCover7] = getNbrTestingIndexes(nbr_testing_samples)

    typecover1_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 1)]
    typecover2_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 2)]
    typecover3_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 3)]
    typecover4_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 4)]
    typecover5_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 5)]
    typecover6_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 6)]
    typecover7_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 7)]
    
    indexesTypeCover1Array = []
    indexesTypeCover2Array = []
    indexesTypeCover3Array = []
    indexesTypeCover4Array = []
    indexesTypeCover5Array = []
    indexesTypeCover6Array = []
    indexesTypeCover7Array = []
    
    for i in range(1, len(training_indexes)+1):
        if(i == 1):
            indexesTypeCover1Array = training_indexes[i-1]
        elif(i == 2):
            indexesTypeCover2Array = training_indexes[i-1]
        elif(i == 3):
            indexesTypeCover3Array = training_indexes[i-1]
        elif(i == 4):
            indexesTypeCover4Array = training_indexes[i-1]
        elif(i == 5):
            indexesTypeCover5Array = training_indexes[i-1]
        elif(i == 6):
            indexesTypeCover6Array = training_indexes[i-1]
        elif(i == 7):
            indexesTypeCover7Array = training_indexes[i-1]

    typecover1_dataSet = numpy.delete(typecover1_dataSet, indexesTypeCover1Array, axis=0)
    typecover2_dataSet = numpy.delete(typecover2_dataSet, indexesTypeCover2Array, axis=0)
    typecover3_dataSet = numpy.delete(typecover3_dataSet, indexesTypeCover3Array, axis=0)
    typecover4_dataSet = numpy.delete(typecover4_dataSet, indexesTypeCover4Array, axis=0)
    typecover5_dataSet = numpy.delete(typecover5_dataSet, indexesTypeCover5Array, axis=0)
    typecover6_dataSet = numpy.delete(typecover6_dataSet, indexesTypeCover6Array, axis=0)
    typecover7_dataSet = numpy.delete(typecover7_dataSet, indexesTypeCover7Array, axis=0)    

    
    if (use_all == True):
        X_typecover1_dataSet =  numpy.array(typecover1_dataSet)[:,0:53]
        X_typecover2_dataSet =  numpy.array(typecover2_dataSet)[:,0:53]
        X_typecover3_dataSet =  numpy.array(typecover3_dataSet)[:,0:53]
        X_typecover4_dataSet =  numpy.array(typecover4_dataSet)[:,0:53]
        X_typecover5_dataSet =  numpy.array(typecover5_dataSet)[:,0:53]
        X_typecover6_dataSet =  numpy.array(typecover6_dataSet)[:,0:53]
        X_typecover7_dataSet =  numpy.array(typecover7_dataSet)[:,0:53]
        X_test = numpy.concatenate((X_typecover1_dataSet, X_typecover2_dataSet, X_typecover3_dataSet, X_typecover4_dataSet, X_typecover5_dataSet, X_typecover6_dataSet, X_typecover7_dataSet), axis=0)

        Y_typecover1_dataSet =  numpy.array(typecover1_dataSet)[:,55:61]
        Y_typecover2_dataSet =  numpy.array(typecover2_dataSet)[:,55:61]
        Y_typecover3_dataSet =  numpy.array(typecover3_dataSet)[:,55:61]
        Y_typecover4_dataSet =  numpy.array(typecover4_dataSet)[:,55:61]
        Y_typecover5_dataSet =  numpy.array(typecover5_dataSet)[:,55:61]
        Y_typecover6_dataSet =  numpy.array(typecover6_dataSet)[:,55:61]
        Y_typecover7_dataSet =  numpy.array(typecover7_dataSet)[:,55:61]
        Y_test = numpy.concatenate((Y_typecover1_dataSet, Y_typecover2_dataSet, Y_typecover3_dataSet, Y_typecover4_dataSet, Y_typecover5_dataSet, Y_typecover6_dataSet, Y_typecover7_dataSet), axis=0)
    return [X_test, Y_test]

class LossHistory(cb.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        batch_loss = logs.get('loss')
        self.losses.append(batch_loss)

def init_model():
    model = Sequential()
    model.add(Dense(120, input_dim=53, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(6, activation='softmax'))

    model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False),
              metrics=['accuracy'])
    return model

def plot_losses(losses):
    plt.plot(losses)
    plt.title('Loss per batch')
    plt.show()
    
filePathTrain = 'C:/Users/computer/Desktop/normalized.csv' 

dataSet = numpy.loadtxt(filePathTrain, delimiter=",")
#X_train = dataSet[0:3780,0:53]
#Y_train = dataSet[0:3780,55:61]
#X_test = dataSet[3000:3780,0:53]
#Y_test = dataSet[3000:3780,55:61]
[X_train, Y_train, indexes] =  getTrainingSet(dataSet, 11340)
[X_test, Y_test] =  getTestSet(dataSet, indexes, 569672, True)

print('X Training:' + str(X_train.shape))
print('Y Training:' + str(Y_train.shape))
print('X Testing:' + str(X_test.shape))
print('Y Testing:' + str(Y_test.shape))

model = init_model()
history = LossHistory()
model.fit(X_train, Y_train, epochs=10000, batch_size=512, callbacks=[history])
print("")
print("Training Set Results:")
score = model.evaluate(X_train, Y_train)
print(score)
print("")

print("")
print("Testing Set Results:")
score = model.evaluate(X_test, Y_test)
print(score)
print("")

plot_losses(history.losses)
# Out:
# X Training:(11340, 53)
# Y Training:(11340, 6)
# X Testing:(569672, 53)
# Y Testing:(569672, 6)
# Epoch 1/10000
# 11340/11340 [==============================] - 3s 226us/step - loss: 1.4307 - acc: 0.3177
# Epoch 2/10000
# 11340/11340 [==============================] - 0s 14us/step - loss: 1.1601 - acc: 0.5317
# Epoch 3/10000
# 11340/11340 [==============================] - 0s 14us/step - loss: 0.9900 - acc: 0.6114
# Epoch 4/10000
# 11340/11340 [==============================] - 0s 14us/step - loss: 0.8783 - acc: 0.6469
# Epoch 5/10000
# 11340/11340 [==============================] - 0s 12us/step - loss: 0.8027 - acc: 0.6729
# Epoch 6/10000
# 11340/11340 [==============================] - 0s 12us/step - loss: 0.7585 - acc: 0.6889
# Epoch 7/10000
# 11340/11340 [==============================] - 0s 12us/step - loss: 0.7240 - acc: 0.6987
# Epoch 8/10000
# 11340/11340 [==============================] - 0s 12us/step - loss: 0.7044 - acc: 0.7056
# Epoch 9/10000
# ...

# %% [markdown]
# Arch: 54-120-20-7
# Epochs: 10000
# Minibatch Size: 512
# Dropout: 0.25 For Each Hidden Layer
# Adam: lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False

# %%
#import sys
#print(sys.path)
#print(sys.executable)

import cnn_utils
from matplotlib import pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
import numpy
import keras.callbacks as cb

# fix random seed for reproducibility
numpy.random.seed(0)

def sortData(dataSet):
    
    typecover1_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 1)]
    typecover2_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 2)]
    typecover3_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 3)]
    typecover4_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 4)]
    typecover5_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 5)]
    typecover6_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 6)]
    typecover7_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 7)]
    
    return [typecover1_dataSet, typecover2_dataSet, typecover3_dataSet, typecover4_dataSet, typecover5_dataSet, typecover6_dataSet, typecover7_dataSet]

def getNbrTestingIndexes(nbr_testing_samples):
    
    percentSamplesFromTypeCover1 = 0.364605
    percentSamplesFromTypeCover2 = 0.487599
    percentSamplesFromTypeCover3 = 0.061537
    percentSamplesFromTypeCover4 = 0.004728
    percentSamplesFromTypeCover5 = 0.016339
    percentSamplesFromTypeCover6 = 0.029891
    percentSamplesFromTypeCover7 = 0.0353
    nbrIdxsFromTypeCover1 = numpy.floor(percentSamplesFromTypeCover1*nbr_testing_samples)
    nbrIdxsFromTypeCover2 = numpy.floor(percentSamplesFromTypeCover2*nbr_testing_samples)
    nbrIdxsFromTypeCover3 = numpy.floor(percentSamplesFromTypeCover3*nbr_testing_samples)
    nbrIdxsFromTypeCover4 = numpy.floor(percentSamplesFromTypeCover4*nbr_testing_samples)
    nbrIdxsFromTypeCover5 = numpy.floor(percentSamplesFromTypeCover5*nbr_testing_samples)
    nbrIdxsFromTypeCover6 = numpy.floor(percentSamplesFromTypeCover6*nbr_testing_samples)
    nbrIdxsFromTypeCover7 = numpy.floor(percentSamplesFromTypeCover7*nbr_testing_samples)
    total = nbrIdxsFromTypeCover1+nbrIdxsFromTypeCover2+nbrIdxsFromTypeCover3+nbrIdxsFromTypeCover4+nbrIdxsFromTypeCover5+nbrIdxsFromTypeCover6+nbrIdxsFromTypeCover7
    
    while(total < nbr_testing_samples):
        num = numpy.random.randint(1,7)
        if(num == 1):
            nbrIdxsFromTypeCover1 = nbrIdxsFromTypeCover1 + 1
        elif(num == 2):
            nbrIdxsFromTypeCover2 = nbrIdxsFromTypeCover2 + 1
        elif(num == 3):
            nbrIdxsFromTypeCover3 = nbrIdxsFromTypeCover3 + 1
        elif(num == 4):
            nbrIdxsFromTypeCover4 = nbrIdxsFromTypeCover4 + 1
        elif(num == 5):
            nbrIdxsFromTypeCover5 = nbrIdxsFromTypeCover5 + 1
        elif(num == 6):
            nbrIdxsFromTypeCover6 = nbrIdxsFromTypeCover6 + 1
        elif(num == 7):
            nbrIdxsFromTypeCover7 = nbrIdxsFromTypeCover7 + 1
        total = total + 1

    return [nbrIdxsFromTypeCover1, nbrIdxsFromTypeCover2, nbrIdxsFromTypeCover3, nbrIdxsFromTypeCover4, nbrIdxsFromTypeCover5, nbrIdxsFromTypeCover6, nbrIdxsFromTypeCover7]
    

def getNbrTrainingIndexes(nbr_training_samples):
    
    nbrIdxsFromTypeCover1 = nbr_training_samples/7
    nbrIdxsFromTypeCover2 = nbr_training_samples/7
    nbrIdxsFromTypeCover3 = nbr_training_samples/7
    nbrIdxsFromTypeCover4 = nbr_training_samples/7
    nbrIdxsFromTypeCover5 = nbr_training_samples/7
    nbrIdxsFromTypeCover6 = nbr_training_samples/7
    nbrIdxsFromTypeCover7 = nbr_training_samples/7
    total = nbrIdxsFromTypeCover1+nbrIdxsFromTypeCover2+nbrIdxsFromTypeCover3+nbrIdxsFromTypeCover4+nbrIdxsFromTypeCover5+nbrIdxsFromTypeCover6+nbrIdxsFromTypeCover7
    
    while(total < nbr_training_samples):
        num = numpy.random.randint(1,7)
        if(num == 1):
            nbrIdxsFromTypeCover1 = nbrIdxsFromTypeCover1 + 1
        elif(num == 2):
            nbrIdxsFromTypeCover2 = nbrIdxsFromTypeCover2 + 1
        elif(num == 3):
            nbrIdxsFromTypeCover3 = nbrIdxsFromTypeCover3 + 1
        elif(num == 4):
            nbrIdxsFromTypeCover4 = nbrIdxsFromTypeCover4 + 1
        elif(num == 5):
            nbrIdxsFromTypeCover5 = nbrIdxsFromTypeCover5 + 1
        elif(num == 6):
            nbrIdxsFromTypeCover6 = nbrIdxsFromTypeCover6 + 1
        elif(num == 7):
            nbrIdxsFromTypeCover7 = nbrIdxsFromTypeCover7 + 1
        total = total + 1

    return [nbrIdxsFromTypeCover1, nbrIdxsFromTypeCover2, nbrIdxsFromTypeCover3, nbrIdxsFromTypeCover4, nbrIdxsFromTypeCover5, nbrIdxsFromTypeCover6, nbrIdxsFromTypeCover7]
    
def getTrainingSet(dataSet, nbr_training_samples):
    
    [nbrIdxsFrmTypeCover1, nbrIdxsFrmTypeCover2, nbrIdxsFrmTypeCover3, nbrIdxsFrmTypeCover4, nbrIdxsFrmTypeCover5, nbrIdxsFrmTypeCover6, nbrIdxsFrmTypeCover7] = getNbrTrainingIndexes(nbr_training_samples)
    [typecover1_dataSet, typecover2_dataSet, typecover3_dataSet, typecover4_dataSet, typecover5_dataSet, typecover6_dataSet, typecover7_dataSet] = sortData(dataSet)
    
    indexesTypeCover1Array = []
    indexesTypeCover2Array = []
    indexesTypeCover3Array = []
    indexesTypeCover4Array = []
    indexesTypeCover5Array = []
    indexesTypeCover6Array = []
    indexesTypeCover7Array = []
    
    for i in range(0, nbr_training_samples-1):
        if(nbrIdxsFrmTypeCover1-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            while(idx in indexesTypeCover1Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            indexesTypeCover1Array.append(idx)
        if(nbrIdxsFrmTypeCover2-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            while(idx in indexesTypeCover2Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover2)
            indexesTypeCover2Array.append(idx)
        if(nbrIdxsFrmTypeCover3-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover3)
            while(idx in indexesTypeCover3Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover3)
            indexesTypeCover3Array.append(idx)
        if(nbrIdxsFrmTypeCover4-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover4)
            while(idx in indexesTypeCover4Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover4)
            indexesTypeCover4Array.append(idx)  
        if(nbrIdxsFrmTypeCover5-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover5)
            while(idx in indexesTypeCover5Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover5)
            indexesTypeCover5Array.append(idx) 
        if(nbrIdxsFrmTypeCover6-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover6)
            while(idx in indexesTypeCover6Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover6)
            indexesTypeCover6Array.append(idx)  
        if(nbrIdxsFrmTypeCover7-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover7)
            while(idx in indexesTypeCover7Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover7)
            indexesTypeCover7Array.append(idx)
    
    X_train_TypeCover1 = numpy.array(typecover1_dataSet)[indexesTypeCover1Array,0:53]
    X_train_TypeCover2 = numpy.array(typecover2_dataSet)[indexesTypeCover2Array,0:53]
    X_train_TypeCover3 = numpy.array(typecover3_dataSet)[indexesTypeCover3Array,0:53]
    X_train_TypeCover4 = numpy.array(typecover4_dataSet)[indexesTypeCover4Array,0:53]
    X_train_TypeCover5 = numpy.array(typecover5_dataSet)[indexesTypeCover5Array,0:53]
    X_train_TypeCover6 = numpy.array(typecover6_dataSet)[indexesTypeCover6Array,0:53]
    X_train_TypeCover7 = numpy.array(typecover7_dataSet)[indexesTypeCover7Array,0:53]

    Y_test_TypeCover1 = numpy.array(typecover1_dataSet)[indexesTypeCover1Array,55:61]
    Y_test_TypeCover2 = numpy.array(typecover2_dataSet)[indexesTypeCover2Array,55:61]
    Y_test_TypeCover3 = numpy.array(typecover3_dataSet)[indexesTypeCover3Array,55:61]
    Y_test_TypeCover4 = numpy.array(typecover4_dataSet)[indexesTypeCover5Array,55:61]
    Y_test_TypeCover5 = numpy.array(typecover5_dataSet)[indexesTypeCover5Array,55:61]
    Y_test_TypeCover6 = numpy.array(typecover6_dataSet)[indexesTypeCover6Array,55:61]
    Y_test_TypeCover7 = numpy.array(typecover7_dataSet)[indexesTypeCover7Array,55:61]
    Y_train = numpy.concatenate((Y_test_TypeCover1, Y_test_TypeCover2, Y_test_TypeCover3, Y_test_TypeCover4, Y_test_TypeCover5, Y_test_TypeCover6, Y_test_TypeCover7), axis=0)
    indexes = [indexesTypeCover1Array, indexesTypeCover2Array, indexesTypeCover3Array, indexesTypeCover4Array, indexesTypeCover5Array, indexesTypeCover6Array, indexesTypeCover7Array]
    
    return [X_train, Y_train, indexes]


def getTestSet(dataSet, training_indexes, nbr_testing_samples, use_all):
    
    [nbrIdxsFrmTypeCover1, nbrIdxsFrmTypeCover2, nbrIdxsFrmTypeCover3, nbrIdxsFrmTypeCover4, nbrIdxsFrmTypeCover5, nbrIdxsFrmTypeCover6, nbrIdxsFrmTypeCover7] = getNbrTestingIndexes(nbr_testing_samples)

    typecover1_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 1)]
    typecover2_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 2)]
    typecover3_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 3)]
    typecover4_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 4)]
    typecover5_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 5)]
    typecover6_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 6)]
    typecover7_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 7)]
    
    indexesTypeCover1Array = []
    indexesTypeCover2Array = []
    indexesTypeCover3Array = []
    indexesTypeCover4Array = []
    indexesTypeCover5Array = []
    indexesTypeCover6Array = []
    indexesTypeCover7Array = []
    
    for i in range(1, len(training_indexes)+1):
        if(i == 1):
            indexesTypeCover1Array = training_indexes[i-1]
        elif(i == 2):
            indexesTypeCover2Array = training_indexes[i-1]
        elif(i == 3):
            indexesTypeCover3Array = training_indexes[i-1]
        elif(i == 4):
            indexesTypeCover4Array = training_indexes[i-1]
        elif(i == 5):
            indexesTypeCover5Array = training_indexes[i-1]
        elif(i == 6):
            indexesTypeCover6Array = training_indexes[i-1]
        elif(i == 7):
            indexesTypeCover7Array = training_indexes[i-1]

    typecover1_dataSet = numpy.delete(typecover1_dataSet, indexesTypeCover1Array, axis=0)
    typecover2_dataSet = numpy.delete(typecover2_dataSet, indexesTypeCover2Array, axis=0)
    typecover3_dataSet = numpy.delete(typecover3_dataSet, indexesTypeCover3Array, axis=0)
    typecover4_dataSet = numpy.delete(typecover4_dataSet, indexesTypeCover4Array, axis=0)
    typecover5_dataSet = numpy.delete(typecover5_dataSet, indexesTypeCover5Array, axis=0)
    typecover6_dataSet = numpy.delete(typecover6_dataSet, indexesTypeCover6Array, axis=0)
    typecover7_dataSet = numpy.delete(typecover7_dataSet, indexesTypeCover7Array, axis=0)    

    
    if (use_all == True):
        X_typecover1_dataSet =  numpy.array(typecover1_dataSet)[:,0:53]
        X_typecover2_dataSet =  numpy.array(typecover2_dataSet)[:,0:53]
        X_typecover3_dataSet =  numpy.array(typecover3_dataSet)[:,0:53]
        X_typecover4_dataSet =  numpy.array(typecover4_dataSet)[:,0:53]
        X_typecover5_dataSet =  numpy.array(typecover5_dataSet)[:,0:53]
        X_typecover6_dataSet =  numpy.array(typecover6_dataSet)[:,0:53]
        X_typecover7_dataSet =  numpy.array(typecover7_dataSet)[:,0:53]
        X_test = numpy.concatenate((X_typecover1_dataSet, X_typecover2_dataSet, X_typecover3_dataSet, X_typecover4_dataSet, X_typecover5_dataSet, X_typecover6_dataSet, X_typecover7_dataSet), axis=0)

        Y_typecover1_dataSet =  numpy.array(typecover1_dataSet)[:,55:61]
        Y_typecover2_dataSet =  numpy.array(typecover2_dataSet)[:,55:61]
        Y_typecover3_dataSet =  numpy.array(typecover3_dataSet)[:,55:61]
        Y_typecover4_dataSet =  numpy.array(typecover4_dataSet)[:,55:61]
        Y_typecover5_dataSet =  numpy.array(typecover5_dataSet)[:,55:61]
        Y_typecover6_dataSet =  numpy.array(typecover6_dataSet)[:,55:61]
        Y_typecover7_dataSet =  numpy.array(typecover7_dataSet)[:,55:61]
        Y_test = numpy.concatenate((Y_typecover1_dataSet, Y_typecover2_dataSet, Y_typecover3_dataSet, Y_typecover4_dataSet, Y_typecover5_dataSet, Y_typecover6_dataSet, Y_typecover7_dataSet), axis=0)
    return [X_test, Y_test]

class LossHistory(cb.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        batch_loss = logs.get('loss')
        self.losses.append(batch_loss)

def init_model():
    model = Sequential()
    model.add(Dense(120, input_dim=53, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(20, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(6, activation='softmax'))

    model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False),
              metrics=['accuracy'])
    return model

def plot_losses(losses):
    plt.plot(losses)
    plt.title('Loss per batch')
    plt.show()
    
filePathTrain = 'C:/Users/computer/Desktop/normalized.csv' 

dataSet = numpy.loadtxt(filePathTrain, delimiter=",")
#X_train = dataSet[0:3780,0:53]
#Y_train = dataSet[0:3780,55:61]
#X_test = dataSet[3000:3780,0:53]
#Y_test = dataSet[3000:3780,55:61]
[X_train, Y_train, indexes] =  getTrainingSet(dataSet, 11340)
[X_test, Y_test] =  getTestSet(dataSet, indexes, 569672, True)

print('X Training:' + str(X_train.shape))
print('Y Training:' + str(Y_train.shape))
print('X Testing:' + str(X_test.shape))
print('Y Testing:' + str(Y_test.shape))

model = init_model()
history = LossHistory()
model.fit(X_train, Y_train, epochs=10000, batch_size=512, callbacks=[history])
print("")
print("Training Set Results:")
score = model.evaluate(X_train, Y_train)
print(score)
print("")

print("")
print("Testing Set Results:")
score = model.evaluate(X_test, Y_test)
print(score)
print("")

plot_losses(history.losses)
# Out:
# X Training:(11340, 53)
# Y Training:(11340, 6)
# X Testing:(569672, 53)
# Y Testing:(569672, 6)
# Epoch 1/10000
# 11340/11340 [==============================] - 2s 203us/step - loss: 1.4218 - acc: 0.3153
# Epoch 2/10000
# 11340/11340 [==============================] - 0s 11us/step - loss: 1.1836 - acc: 0.4913
# Epoch 3/10000
# 11340/11340 [==============================] - 0s 11us/step - loss: 0.9979 - acc: 0.5700
# Epoch 4/10000
# 11340/11340 [==============================] - 0s 12us/step - loss: 0.8994 - acc: 0.6095
# Epoch 5/10000
# 11340/11340 [==============================] - 0s 11us/step - loss: 0.8382 - acc: 0.6371
# Epoch 6/10000
# 11340/11340 [==============================] - 0s 11us/step - loss: 0.7937 - acc: 0.6520
# Epoch 7/10000
# 11340/11340 [==============================] - 0s 11us/step - loss: 0.7642 - acc: 0.6690
# Epoch 8/10000
# 11340/11340 [==============================] - 0s 11us/step - loss: 0.7448 - acc: 0.6807
# Epoch 9/10000
# ...

# %% [markdown]
# Arch: 54-1024-512-216-7
# Epochs: 2000
# Minibatch Size: 512
# Dropout: 0.25 For Each Hidden Layer
# Adam: lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False

# %%
#import sys
#print(sys.path)
#print(sys.executable)

import cnn_utils
from matplotlib import pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
import numpy
import keras.callbacks as cb

# fix random seed for reproducibility
numpy.random.seed(0)

def sortData(dataSet):
    
    typecover1_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 1)]
    typecover2_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 2)]
    typecover3_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 3)]
    typecover4_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 4)]
    typecover5_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 5)]
    typecover6_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 6)]
    typecover7_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 7)]
    
    return [typecover1_dataSet, typecover2_dataSet, typecover3_dataSet, typecover4_dataSet, typecover5_dataSet, typecover6_dataSet, typecover7_dataSet]

def getNbrTestingIndexes(nbr_testing_samples):
    
    percentSamplesFromTypeCover1 = 0.364605
    percentSamplesFromTypeCover2 = 0.487599
    percentSamplesFromTypeCover3 = 0.061537
    percentSamplesFromTypeCover4 = 0.004728
    percentSamplesFromTypeCover5 = 0.016339
    percentSamplesFromTypeCover6 = 0.029891
    percentSamplesFromTypeCover7 = 0.0353
    nbrIdxsFromTypeCover1 = numpy.floor(percentSamplesFromTypeCover1*nbr_testing_samples)
    nbrIdxsFromTypeCover2 = numpy.floor(percentSamplesFromTypeCover2*nbr_testing_samples)
    nbrIdxsFromTypeCover3 = numpy.floor(percentSamplesFromTypeCover3*nbr_testing_samples)
    nbrIdxsFromTypeCover4 = numpy.floor(percentSamplesFromTypeCover4*nbr_testing_samples)
    nbrIdxsFromTypeCover5 = numpy.floor(percentSamplesFromTypeCover5*nbr_testing_samples)
    nbrIdxsFromTypeCover6 = numpy.floor(percentSamplesFromTypeCover6*nbr_testing_samples)
    nbrIdxsFromTypeCover7 = numpy.floor(percentSamplesFromTypeCover7*nbr_testing_samples)
    total = nbrIdxsFromTypeCover1+nbrIdxsFromTypeCover2+nbrIdxsFromTypeCover3+nbrIdxsFromTypeCover4+nbrIdxsFromTypeCover5+nbrIdxsFromTypeCover6+nbrIdxsFromTypeCover7
    
    while(total < nbr_testing_samples):
        num = numpy.random.randint(1,7)
        if(num == 1):
            nbrIdxsFromTypeCover1 = nbrIdxsFromTypeCover1 + 1
        elif(num == 2):
            nbrIdxsFromTypeCover2 = nbrIdxsFromTypeCover2 + 1
        elif(num == 3):
            nbrIdxsFromTypeCover3 = nbrIdxsFromTypeCover3 + 1
        elif(num == 4):
            nbrIdxsFromTypeCover4 = nbrIdxsFromTypeCover4 + 1
        elif(num == 5):
            nbrIdxsFromTypeCover5 = nbrIdxsFromTypeCover5 + 1
        elif(num == 6):
            nbrIdxsFromTypeCover6 = nbrIdxsFromTypeCover6 + 1
        elif(num == 7):
            nbrIdxsFromTypeCover7 = nbrIdxsFromTypeCover7 + 1
        total = total + 1

    return [nbrIdxsFromTypeCover1, nbrIdxsFromTypeCover2, nbrIdxsFromTypeCover3, nbrIdxsFromTypeCover4, nbrIdxsFromTypeCover5, nbrIdxsFromTypeCover6, nbrIdxsFromTypeCover7]
    

def getNbrTrainingIndexes(nbr_training_samples):
    
    nbrIdxsFromTypeCover1 = nbr_training_samples/7
    nbrIdxsFromTypeCover2 = nbr_training_samples/7
    nbrIdxsFromTypeCover3 = nbr_training_samples/7
    nbrIdxsFromTypeCover4 = nbr_training_samples/7
    nbrIdxsFromTypeCover5 = nbr_training_samples/7
    nbrIdxsFromTypeCover6 = nbr_training_samples/7
    nbrIdxsFromTypeCover7 = nbr_training_samples/7
    total = nbrIdxsFromTypeCover1+nbrIdxsFromTypeCover2+nbrIdxsFromTypeCover3+nbrIdxsFromTypeCover4+nbrIdxsFromTypeCover5+nbrIdxsFromTypeCover6+nbrIdxsFromTypeCover7
    
    while(total < nbr_training_samples):
        num = numpy.random.randint(1,7)
        if(num == 1):
            nbrIdxsFromTypeCover1 = nbrIdxsFromTypeCover1 + 1
        elif(num == 2):
            nbrIdxsFromTypeCover2 = nbrIdxsFromTypeCover2 + 1
        elif(num == 3):
            nbrIdxsFromTypeCover3 = nbrIdxsFromTypeCover3 + 1
        elif(num == 4):
            nbrIdxsFromTypeCover4 = nbrIdxsFromTypeCover4 + 1
        elif(num == 5):
            nbrIdxsFromTypeCover5 = nbrIdxsFromTypeCover5 + 1
        elif(num == 6):
            nbrIdxsFromTypeCover6 = nbrIdxsFromTypeCover6 + 1
        elif(num == 7):
            nbrIdxsFromTypeCover7 = nbrIdxsFromTypeCover7 + 1
        total = total + 1

    return [nbrIdxsFromTypeCover1, nbrIdxsFromTypeCover2, nbrIdxsFromTypeCover3, nbrIdxsFromTypeCover4, nbrIdxsFromTypeCover5, nbrIdxsFromTypeCover6, nbrIdxsFromTypeCover7]
    
def getTrainingSet(dataSet, nbr_training_samples):
    
    [nbrIdxsFrmTypeCover1, nbrIdxsFrmTypeCover2, nbrIdxsFrmTypeCover3, nbrIdxsFrmTypeCover4, nbrIdxsFrmTypeCover5, nbrIdxsFrmTypeCover6, nbrIdxsFrmTypeCover7] = getNbrTrainingIndexes(nbr_training_samples)
    [typecover1_dataSet, typecover2_dataSet, typecover3_dataSet, typecover4_dataSet, typecover5_dataSet, typecover6_dataSet, typecover7_dataSet] = sortData(dataSet)
    
    indexesTypeCover1Array = []
    indexesTypeCover2Array = []
    indexesTypeCover3Array = []
    indexesTypeCover4Array = []
    indexesTypeCover5Array = []
    indexesTypeCover6Array = []
    indexesTypeCover7Array = []
    
    for i in range(0, nbr_training_samples-1):
        if(nbrIdxsFrmTypeCover1-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            while(idx in indexesTypeCover1Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            indexesTypeCover1Array.append(idx)
        if(nbrIdxsFrmTypeCover2-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            while(idx in indexesTypeCover2Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover2)
            indexesTypeCover2Array.append(idx)
        if(nbrIdxsFrmTypeCover3-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover3)
            while(idx in indexesTypeCover3Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover3)
            indexesTypeCover3Array.append(idx)
        if(nbrIdxsFrmTypeCover4-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover4)
            while(idx in indexesTypeCover4Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover4)
            indexesTypeCover4Array.append(idx)  
        if(nbrIdxsFrmTypeCover5-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover5)
            while(idx in indexesTypeCover5Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover5)
            indexesTypeCover5Array.append(idx) 
        if(nbrIdxsFrmTypeCover6-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover6)
            while(idx in indexesTypeCover6Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover6)
            indexesTypeCover6Array.append(idx)  
        if(nbrIdxsFrmTypeCover7-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover7)
            while(idx in indexesTypeCover7Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover7)
            indexesTypeCover7Array.append(idx)
    
    X_train_TypeCover1 = numpy.array(typecover1_dataSet)[indexesTypeCover1Array,0:53]
    X_train_TypeCover2 = numpy.array(typecover2_dataSet)[indexesTypeCover2Array,0:53]
    X_train_TypeCover3 = numpy.array(typecover3_dataSet)[indexesTypeCover3Array,0:53]
    X_train_TypeCover4 = numpy.array(typecover4_dataSet)[indexesTypeCover4Array,0:53]
    X_train_TypeCover5 = numpy.array(typecover5_dataSet)[indexesTypeCover5Array,0:53]
    X_train_TypeCover6 = numpy.array(typecover6_dataSet)[indexesTypeCover6Array,0:53]
    X_train_TypeCover7 = numpy.array(typecover7_dataSet)[indexesTypeCover7Array,0:53]

    Y_test_TypeCover1 = numpy.array(typecover1_dataSet)[indexesTypeCover1Array,55:61]
    Y_test_TypeCover2 = numpy.array(typecover2_dataSet)[indexesTypeCover2Array,55:61]
    Y_test_TypeCover3 = numpy.array(typecover3_dataSet)[indexesTypeCover3Array,55:61]
    Y_test_TypeCover4 = numpy.array(typecover4_dataSet)[indexesTypeCover5Array,55:61]
    Y_test_TypeCover5 = numpy.array(typecover5_dataSet)[indexesTypeCover5Array,55:61]
    Y_test_TypeCover6 = numpy.array(typecover6_dataSet)[indexesTypeCover6Array,55:61]
    Y_test_TypeCover7 = numpy.array(typecover7_dataSet)[indexesTypeCover7Array,55:61]
    Y_train = numpy.concatenate((Y_test_TypeCover1, Y_test_TypeCover2, Y_test_TypeCover3, Y_test_TypeCover4, Y_test_TypeCover5, Y_test_TypeCover6, Y_test_TypeCover7), axis=0)
    indexes = [indexesTypeCover1Array, indexesTypeCover2Array, indexesTypeCover3Array, indexesTypeCover4Array, indexesTypeCover5Array, indexesTypeCover6Array, indexesTypeCover7Array]
    
    return [X_train, Y_train, indexes]


def getTestSet(dataSet, training_indexes, nbr_testing_samples, use_all):
    
    [nbrIdxsFrmTypeCover1, nbrIdxsFrmTypeCover2, nbrIdxsFrmTypeCover3, nbrIdxsFrmTypeCover4, nbrIdxsFrmTypeCover5, nbrIdxsFrmTypeCover6, nbrIdxsFrmTypeCover7] = getNbrTestingIndexes(nbr_testing_samples)

    typecover1_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 1)]
    typecover2_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 2)]
    typecover3_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 3)]
    typecover4_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 4)]
    typecover5_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 5)]
    typecover6_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 6)]
    typecover7_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 7)]
    
    indexesTypeCover1Array = []
    indexesTypeCover2Array = []
    indexesTypeCover3Array = []
    indexesTypeCover4Array = []
    indexesTypeCover5Array = []
    indexesTypeCover6Array = []
    indexesTypeCover7Array = []
    
    for i in range(1, len(training_indexes)+1):
        if(i == 1):
            indexesTypeCover1Array = training_indexes[i-1]
        elif(i == 2):
            indexesTypeCover2Array = training_indexes[i-1]
        elif(i == 3):
            indexesTypeCover3Array = training_indexes[i-1]
        elif(i == 4):
            indexesTypeCover4Array = training_indexes[i-1]
        elif(i == 5):
            indexesTypeCover5Array = training_indexes[i-1]
        elif(i == 6):
            indexesTypeCover6Array = training_indexes[i-1]
        elif(i == 7):
            indexesTypeCover7Array = training_indexes[i-1]

    typecover1_dataSet = numpy.delete(typecover1_dataSet, indexesTypeCover1Array, axis=0)
    typecover2_dataSet = numpy.delete(typecover2_dataSet, indexesTypeCover2Array, axis=0)
    typecover3_dataSet = numpy.delete(typecover3_dataSet, indexesTypeCover3Array, axis=0)
    typecover4_dataSet = numpy.delete(typecover4_dataSet, indexesTypeCover4Array, axis=0)
    typecover5_dataSet = numpy.delete(typecover5_dataSet, indexesTypeCover5Array, axis=0)
    typecover6_dataSet = numpy.delete(typecover6_dataSet, indexesTypeCover6Array, axis=0)
    typecover7_dataSet = numpy.delete(typecover7_dataSet, indexesTypeCover7Array, axis=0)    

    
    if (use_all == True):
        X_typecover1_dataSet =  numpy.array(typecover1_dataSet)[:,0:53]
        X_typecover2_dataSet =  numpy.array(typecover2_dataSet)[:,0:53]
        X_typecover3_dataSet =  numpy.array(typecover3_dataSet)[:,0:53]
        X_typecover4_dataSet =  numpy.array(typecover4_dataSet)[:,0:53]
        X_typecover5_dataSet =  numpy.array(typecover5_dataSet)[:,0:53]
        X_typecover6_dataSet =  numpy.array(typecover6_dataSet)[:,0:53]
        X_typecover7_dataSet =  numpy.array(typecover7_dataSet)[:,0:53]
        X_test = numpy.concatenate((X_typecover1_dataSet, X_typecover2_dataSet, X_typecover3_dataSet, X_typecover4_dataSet, X_typecover5_dataSet, X_typecover6_dataSet, X_typecover7_dataSet), axis=0)

        Y_typecover1_dataSet =  numpy.array(typecover1_dataSet)[:,55:61]
        Y_typecover2_dataSet =  numpy.array(typecover2_dataSet)[:,55:61]
        Y_typecover3_dataSet =  numpy.array(typecover3_dataSet)[:,55:61]
        Y_typecover4_dataSet =  numpy.array(typecover4_dataSet)[:,55:61]
        Y_typecover5_dataSet =  numpy.array(typecover5_dataSet)[:,55:61]
        Y_typecover6_dataSet =  numpy.array(typecover6_dataSet)[:,55:61]
        Y_typecover7_dataSet =  numpy.array(typecover7_dataSet)[:,55:61]
        Y_test = numpy.concatenate((Y_typecover1_dataSet, Y_typecover2_dataSet, Y_typecover3_dataSet, Y_typecover4_dataSet, Y_typecover5_dataSet, Y_typecover6_dataSet, Y_typecover7_dataSet), axis=0)
    return [X_test, Y_test]

class LossHistory(cb.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        batch_loss = logs.get('loss')
        self.losses.append(batch_loss)

def init_model():
    model = Sequential()
    model.add(Dense(1028, input_dim=53, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(216, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(6, activation='softmax'))

    model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False),
              metrics=['accuracy'])
    return model

def plot_losses(losses):
    plt.plot(losses)
    plt.title('Loss per batch')
    plt.show()
    
filePathTrain = 'C:/Users/computer/Desktop/normalized.csv' 

dataSet = numpy.loadtxt(filePathTrain, delimiter=",")
#X_train = dataSet[0:3780,0:53]
#Y_train = dataSet[0:3780,55:61]
#X_test = dataSet[3000:3780,0:53]
#Y_test = dataSet[3000:3780,55:61]
[X_train, Y_train, indexes] =  getTrainingSet(dataSet, 11340)
[X_test, Y_test] =  getTestSet(dataSet, indexes, 569672, True)

print('X Training:' + str(X_train.shape))
print('Y Training:' + str(Y_train.shape))
print('X Testing:' + str(X_test.shape))
print('Y Testing:' + str(Y_test.shape))

model = init_model()
history = LossHistory()
model.fit(X_train, Y_train, epochs=2000, batch_size=512, callbacks=[history])
print("")
print("Training Set Results:")
score = model.evaluate(X_train, Y_train)
print(score)
print("")

print("")
print("Testing Set Results:")
score = model.evaluate(X_test, Y_test)
print(score)
print("")

plot_losses(history.losses)
# Out:
# X Training:(11340, 53)
# Y Training:(11340, 6)
# X Testing:(569672, 53)
# Y Testing:(569672, 6)
# Epoch 1/2000
# 11340/11340 [==============================] - 3s 223us/step - loss: 0.9526 - acc: 0.5951
# Epoch 2/2000
# 11340/11340 [==============================] - 0s 18us/step - loss: 0.6563 - acc: 0.7073
# Epoch 3/2000
# 11340/11340 [==============================] - 0s 16us/step - loss: 0.5826 - acc: 0.7528
# Epoch 4/2000
# 11340/11340 [==============================] - 0s 18us/step - loss: 0.5549 - acc: 0.7583
# Epoch 5/2000
# 11340/11340 [==============================] - 0s 17us/step - loss: 0.5331 - acc: 0.7678
# Epoch 6/2000
# 11340/11340 [==============================] - 0s 17us/step - loss: 0.5126 - acc: 0.7784
# Epoch 7/2000
# 11340/11340 [==============================] - 0s 26us/step - loss: 0.4926 - acc: 0.7889
# Epoch 8/2000
# 11340/11340 [==============================] - 0s 21us/step - loss: 0.4772 - acc: 0.7979
# Epoch 9/2000
# ...

# %% [markdown]
# Arch: 54-1024-512-216-7
# Epochs: 2000
# Minibatch Size: 512
# Dropout: 0.25 For Each Hidden Layer
# L1: 0.00001 For Each Hidden Layer
# Adam: lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False

# %%
#import sys
#print(sys.path)
#print(sys.executable)

import cnn_utils
from matplotlib import pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
import numpy
import keras.callbacks as cb
from keras import regularizers

# fix random seed for reproducibility
numpy.random.seed(0)

def sortData(dataSet):
    
    typecover1_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 1)]
    typecover2_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 2)]
    typecover3_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 3)]
    typecover4_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 4)]
    typecover5_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 5)]
    typecover6_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 6)]
    typecover7_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 7)]
    
    return [typecover1_dataSet, typecover2_dataSet, typecover3_dataSet, typecover4_dataSet, typecover5_dataSet, typecover6_dataSet, typecover7_dataSet]

def getNbrTestingIndexes(nbr_testing_samples):
    
    percentSamplesFromTypeCover1 = 0.364605
    percentSamplesFromTypeCover2 = 0.487599
    percentSamplesFromTypeCover3 = 0.061537
    percentSamplesFromTypeCover4 = 0.004728
    percentSamplesFromTypeCover5 = 0.016339
    percentSamplesFromTypeCover6 = 0.029891
    percentSamplesFromTypeCover7 = 0.0353
    nbrIdxsFromTypeCover1 = numpy.floor(percentSamplesFromTypeCover1*nbr_testing_samples)
    nbrIdxsFromTypeCover2 = numpy.floor(percentSamplesFromTypeCover2*nbr_testing_samples)
    nbrIdxsFromTypeCover3 = numpy.floor(percentSamplesFromTypeCover3*nbr_testing_samples)
    nbrIdxsFromTypeCover4 = numpy.floor(percentSamplesFromTypeCover4*nbr_testing_samples)
    nbrIdxsFromTypeCover5 = numpy.floor(percentSamplesFromTypeCover5*nbr_testing_samples)
    nbrIdxsFromTypeCover6 = numpy.floor(percentSamplesFromTypeCover6*nbr_testing_samples)
    nbrIdxsFromTypeCover7 = numpy.floor(percentSamplesFromTypeCover7*nbr_testing_samples)
    total = nbrIdxsFromTypeCover1+nbrIdxsFromTypeCover2+nbrIdxsFromTypeCover3+nbrIdxsFromTypeCover4+nbrIdxsFromTypeCover5+nbrIdxsFromTypeCover6+nbrIdxsFromTypeCover7
    
    while(total < nbr_testing_samples):
        num = numpy.random.randint(1,7)
        if(num == 1):
            nbrIdxsFromTypeCover1 = nbrIdxsFromTypeCover1 + 1
        elif(num == 2):
            nbrIdxsFromTypeCover2 = nbrIdxsFromTypeCover2 + 1
        elif(num == 3):
            nbrIdxsFromTypeCover3 = nbrIdxsFromTypeCover3 + 1
        elif(num == 4):
            nbrIdxsFromTypeCover4 = nbrIdxsFromTypeCover4 + 1
        elif(num == 5):
            nbrIdxsFromTypeCover5 = nbrIdxsFromTypeCover5 + 1
        elif(num == 6):
            nbrIdxsFromTypeCover6 = nbrIdxsFromTypeCover6 + 1
        elif(num == 7):
            nbrIdxsFromTypeCover7 = nbrIdxsFromTypeCover7 + 1
        total = total + 1

    return [nbrIdxsFromTypeCover1, nbrIdxsFromTypeCover2, nbrIdxsFromTypeCover3, nbrIdxsFromTypeCover4, nbrIdxsFromTypeCover5, nbrIdxsFromTypeCover6, nbrIdxsFromTypeCover7]
    

def getNbrTrainingIndexes(nbr_training_samples):
    
    nbrIdxsFromTypeCover1 = nbr_training_samples/7
    nbrIdxsFromTypeCover2 = nbr_training_samples/7
    nbrIdxsFromTypeCover3 = nbr_training_samples/7
    nbrIdxsFromTypeCover4 = nbr_training_samples/7
    nbrIdxsFromTypeCover5 = nbr_training_samples/7
    nbrIdxsFromTypeCover6 = nbr_training_samples/7
    nbrIdxsFromTypeCover7 = nbr_training_samples/7
    total = nbrIdxsFromTypeCover1+nbrIdxsFromTypeCover2+nbrIdxsFromTypeCover3+nbrIdxsFromTypeCover4+nbrIdxsFromTypeCover5+nbrIdxsFromTypeCover6+nbrIdxsFromTypeCover7
    
    while(total < nbr_training_samples):
        num = numpy.random.randint(1,7)
        if(num == 1):
            nbrIdxsFromTypeCover1 = nbrIdxsFromTypeCover1 + 1
        elif(num == 2):
            nbrIdxsFromTypeCover2 = nbrIdxsFromTypeCover2 + 1
        elif(num == 3):
            nbrIdxsFromTypeCover3 = nbrIdxsFromTypeCover3 + 1
        elif(num == 4):
            nbrIdxsFromTypeCover4 = nbrIdxsFromTypeCover4 + 1
        elif(num == 5):
            nbrIdxsFromTypeCover5 = nbrIdxsFromTypeCover5 + 1
        elif(num == 6):
            nbrIdxsFromTypeCover6 = nbrIdxsFromTypeCover6 + 1
        elif(num == 7):
            nbrIdxsFromTypeCover7 = nbrIdxsFromTypeCover7 + 1
        total = total + 1

    return [nbrIdxsFromTypeCover1, nbrIdxsFromTypeCover2, nbrIdxsFromTypeCover3, nbrIdxsFromTypeCover4, nbrIdxsFromTypeCover5, nbrIdxsFromTypeCover6, nbrIdxsFromTypeCover7]
    
def getTrainingSet(dataSet, nbr_training_samples):
    
    [nbrIdxsFrmTypeCover1, nbrIdxsFrmTypeCover2, nbrIdxsFrmTypeCover3, nbrIdxsFrmTypeCover4, nbrIdxsFrmTypeCover5, nbrIdxsFrmTypeCover6, nbrIdxsFrmTypeCover7] = getNbrTrainingIndexes(nbr_training_samples)
    [typecover1_dataSet, typecover2_dataSet, typecover3_dataSet, typecover4_dataSet, typecover5_dataSet, typecover6_dataSet, typecover7_dataSet] = sortData(dataSet)
    
    indexesTypeCover1Array = []
    indexesTypeCover2Array = []
    indexesTypeCover3Array = []
    indexesTypeCover4Array = []
    indexesTypeCover5Array = []
    indexesTypeCover6Array = []
    indexesTypeCover7Array = []
    
    for i in range(0, nbr_training_samples-1):
        if(nbrIdxsFrmTypeCover1-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            while(idx in indexesTypeCover1Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            indexesTypeCover1Array.append(idx)
        if(nbrIdxsFrmTypeCover2-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            while(idx in indexesTypeCover2Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover2)
            indexesTypeCover2Array.append(idx)
        if(nbrIdxsFrmTypeCover3-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover3)
            while(idx in indexesTypeCover3Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover3)
            indexesTypeCover3Array.append(idx)
        if(nbrIdxsFrmTypeCover4-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover4)
            while(idx in indexesTypeCover4Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover4)
            indexesTypeCover4Array.append(idx)  
        if(nbrIdxsFrmTypeCover5-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover5)
            while(idx in indexesTypeCover5Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover5)
            indexesTypeCover5Array.append(idx) 
        if(nbrIdxsFrmTypeCover6-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover6)
            while(idx in indexesTypeCover6Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover6)
            indexesTypeCover6Array.append(idx)  
        if(nbrIdxsFrmTypeCover7-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover7)
            while(idx in indexesTypeCover7Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover7)
            indexesTypeCover7Array.append(idx)
    
    X_train_TypeCover1 = numpy.array(typecover1_dataSet)[indexesTypeCover1Array,0:53]
    X_train_TypeCover2 = numpy.array(typecover2_dataSet)[indexesTypeCover2Array,0:53]
    X_train_TypeCover3 = numpy.array(typecover3_dataSet)[indexesTypeCover3Array,0:53]
    X_train_TypeCover4 = numpy.array(typecover4_dataSet)[indexesTypeCover4Array,0:53]
    X_train_TypeCover5 = numpy.array(typecover5_dataSet)[indexesTypeCover5Array,0:53]
    X_train_TypeCover6 = numpy.array(typecover6_dataSet)[indexesTypeCover6Array,0:53]
    X_train_TypeCover7 = numpy.array(typecover7_dataSet)[indexesTypeCover7Array,0:53]

    Y_test_TypeCover1 = numpy.array(typecover1_dataSet)[indexesTypeCover1Array,55:61]
    Y_test_TypeCover2 = numpy.array(typecover2_dataSet)[indexesTypeCover2Array,55:61]
    Y_test_TypeCover3 = numpy.array(typecover3_dataSet)[indexesTypeCover3Array,55:61]
    Y_test_TypeCover4 = numpy.array(typecover4_dataSet)[indexesTypeCover5Array,55:61]
    Y_test_TypeCover5 = numpy.array(typecover5_dataSet)[indexesTypeCover5Array,55:61]
    Y_test_TypeCover6 = numpy.array(typecover6_dataSet)[indexesTypeCover6Array,55:61]
    Y_test_TypeCover7 = numpy.array(typecover7_dataSet)[indexesTypeCover7Array,55:61]
    Y_train = numpy.concatenate((Y_test_TypeCover1, Y_test_TypeCover2, Y_test_TypeCover3, Y_test_TypeCover4, Y_test_TypeCover5, Y_test_TypeCover6, Y_test_TypeCover7), axis=0)
    indexes = [indexesTypeCover1Array, indexesTypeCover2Array, indexesTypeCover3Array, indexesTypeCover4Array, indexesTypeCover5Array, indexesTypeCover6Array, indexesTypeCover7Array]
    
    return [X_train, Y_train, indexes]


def getTestSet(dataSet, training_indexes, nbr_testing_samples, use_all):
    
    [nbrIdxsFrmTypeCover1, nbrIdxsFrmTypeCover2, nbrIdxsFrmTypeCover3, nbrIdxsFrmTypeCover4, nbrIdxsFrmTypeCover5, nbrIdxsFrmTypeCover6, nbrIdxsFrmTypeCover7] = getNbrTestingIndexes(nbr_testing_samples)

    typecover1_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 1)]
    typecover2_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 2)]
    typecover3_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 3)]
    typecover4_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 4)]
    typecover5_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 5)]
    typecover6_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 6)]
    typecover7_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 7)]
    
    indexesTypeCover1Array = []
    indexesTypeCover2Array = []
    indexesTypeCover3Array = []
    indexesTypeCover4Array = []
    indexesTypeCover5Array = []
    indexesTypeCover6Array = []
    indexesTypeCover7Array = []
    
    for i in range(1, len(training_indexes)+1):
        if(i == 1):
            indexesTypeCover1Array = training_indexes[i-1]
        elif(i == 2):
            indexesTypeCover2Array = training_indexes[i-1]
        elif(i == 3):
            indexesTypeCover3Array = training_indexes[i-1]
        elif(i == 4):
            indexesTypeCover4Array = training_indexes[i-1]
        elif(i == 5):
            indexesTypeCover5Array = training_indexes[i-1]
        elif(i == 6):
            indexesTypeCover6Array = training_indexes[i-1]
        elif(i == 7):
            indexesTypeCover7Array = training_indexes[i-1]

    typecover1_dataSet = numpy.delete(typecover1_dataSet, indexesTypeCover1Array, axis=0)
    typecover2_dataSet = numpy.delete(typecover2_dataSet, indexesTypeCover2Array, axis=0)
    typecover3_dataSet = numpy.delete(typecover3_dataSet, indexesTypeCover3Array, axis=0)
    typecover4_dataSet = numpy.delete(typecover4_dataSet, indexesTypeCover4Array, axis=0)
    typecover5_dataSet = numpy.delete(typecover5_dataSet, indexesTypeCover5Array, axis=0)
    typecover6_dataSet = numpy.delete(typecover6_dataSet, indexesTypeCover6Array, axis=0)
    typecover7_dataSet = numpy.delete(typecover7_dataSet, indexesTypeCover7Array, axis=0)    

    
    if (use_all == True):
        X_typecover1_dataSet =  numpy.array(typecover1_dataSet)[:,0:53]
        X_typecover2_dataSet =  numpy.array(typecover2_dataSet)[:,0:53]
        X_typecover3_dataSet =  numpy.array(typecover3_dataSet)[:,0:53]
        X_typecover4_dataSet =  numpy.array(typecover4_dataSet)[:,0:53]
        X_typecover5_dataSet =  numpy.array(typecover5_dataSet)[:,0:53]
        X_typecover6_dataSet =  numpy.array(typecover6_dataSet)[:,0:53]
        X_typecover7_dataSet =  numpy.array(typecover7_dataSet)[:,0:53]
        X_test = numpy.concatenate((X_typecover1_dataSet, X_typecover2_dataSet, X_typecover3_dataSet, X_typecover4_dataSet, X_typecover5_dataSet, X_typecover6_dataSet, X_typecover7_dataSet), axis=0)

        Y_typecover1_dataSet =  numpy.array(typecover1_dataSet)[:,55:61]
        Y_typecover2_dataSet =  numpy.array(typecover2_dataSet)[:,55:61]
        Y_typecover3_dataSet =  numpy.array(typecover3_dataSet)[:,55:61]
        Y_typecover4_dataSet =  numpy.array(typecover4_dataSet)[:,55:61]
        Y_typecover5_dataSet =  numpy.array(typecover5_dataSet)[:,55:61]
        Y_typecover6_dataSet =  numpy.array(typecover6_dataSet)[:,55:61]
        Y_typecover7_dataSet =  numpy.array(typecover7_dataSet)[:,55:61]
        Y_test = numpy.concatenate((Y_typecover1_dataSet, Y_typecover2_dataSet, Y_typecover3_dataSet, Y_typecover4_dataSet, Y_typecover5_dataSet, Y_typecover6_dataSet, Y_typecover7_dataSet), axis=0)
    return [X_test, Y_test]

class LossHistory(cb.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        batch_loss = logs.get('loss')
        self.losses.append(batch_loss)

def init_model():
    model = Sequential()
    model.add(Dense(1028, input_dim=53, activation='relu', activity_regularizer=regularizers.l1(0.00001)))
    model.add(Dropout(0.25))
    model.add(Dense(512, activation='relu', activity_regularizer=regularizers.l1(0.00001)))
    model.add(Dropout(0.25))
    model.add(Dense(216, activation='relu', activity_regularizer=regularizers.l1(0.00001)))
    model.add(Dropout(0.25))
    model.add(Dense(6, activation='softmax', activity_regularizer=regularizers.l1(0.00001)))

    model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False),
              metrics=['accuracy'])
    return model

def plot_losses(losses):
    plt.plot(losses)
    plt.title('Loss per batch')
    plt.show()
    
filePathTrain = 'C:/Users/computer/Desktop/normalized.csv' 

dataSet = numpy.loadtxt(filePathTrain, delimiter=",")
#X_train = dataSet[0:3780,0:53]
#Y_train = dataSet[0:3780,55:61]
#X_test = dataSet[3000:3780,0:53]
#Y_test = dataSet[3000:3780,55:61]
[X_train, Y_train, indexes] =  getTrainingSet(dataSet, 11340)
[X_test, Y_test] =  getTestSet(dataSet, indexes, 569672, True)

print('X Training:' + str(X_train.shape))
print('Y Training:' + str(Y_train.shape))
print('X Testing:' + str(X_test.shape))
print('Y Testing:' + str(Y_test.shape))

model = init_model()
history = LossHistory()
model.fit(X_train, Y_train, epochs=2000, batch_size=512, callbacks=[history])
print("")
print("Training Set Results:")
score = model.evaluate(X_train, Y_train)
print(score)
print("")

print("")
print("Testing Set Results:")
score = model.evaluate(X_test, Y_test)
print(score)
print("")

plot_losses(history.losses)
# Out:
# X Training:(11340, 53)
# Y Training:(11340, 6)
# X Testing:(569672, 53)
# Y Testing:(569672, 6)
# Epoch 1/2000
# 11340/11340 [==============================] - 3s 258us/step - loss: 1.5424 - acc: 0.5652
# Epoch 2/2000
# 11340/11340 [==============================] - 0s 19us/step - loss: 1.0611 - acc: 0.7066
# Epoch 3/2000
# 11340/11340 [==============================] - 0s 18us/step - loss: 0.8796 - acc: 0.7529
# Epoch 4/2000
# 11340/11340 [==============================] - 0s 18us/step - loss: 0.7899 - acc: 0.7751
# Epoch 5/2000
# 11340/11340 [==============================] - 0s 18us/step - loss: 0.7284 - acc: 0.7852
# Epoch 6/2000
# 11340/11340 [==============================] - 0s 18us/step - loss: 0.6841 - acc: 0.7994
# Epoch 7/2000
# 11340/11340 [==============================] - 0s 18us/step - loss: 0.6472 - acc: 0.8142
# Epoch 8/2000
# 11340/11340 [==============================] - 0s 18us/step - loss: 0.6182 - acc: 0.8160
# Epoch 9/2000
# ...

# %% [markdown]
# Arch: 54-1024-512-216-7
# Epochs: 2000
# Minibatch Size: 512
# Dropout: 0.25 For Each Hidden Layer
# L2: 0.00001 For Each Hidden Layer
# Adam: lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False

# %%
#import sys
#print(sys.path)
#print(sys.executable)

import cnn_utils
from matplotlib import pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
import numpy
import keras.callbacks as cb
from keras import regularizers

# fix random seed for reproducibility
numpy.random.seed(0)

def sortData(dataSet):
    
    typecover1_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 1)]
    typecover2_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 2)]
    typecover3_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 3)]
    typecover4_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 4)]
    typecover5_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 5)]
    typecover6_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 6)]
    typecover7_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 7)]
    
    return [typecover1_dataSet, typecover2_dataSet, typecover3_dataSet, typecover4_dataSet, typecover5_dataSet, typecover6_dataSet, typecover7_dataSet]

def getNbrTestingIndexes(nbr_testing_samples):
    
    percentSamplesFromTypeCover1 = 0.364605
    percentSamplesFromTypeCover2 = 0.487599
    percentSamplesFromTypeCover3 = 0.061537
    percentSamplesFromTypeCover4 = 0.004728
    percentSamplesFromTypeCover5 = 0.016339
    percentSamplesFromTypeCover6 = 0.029891
    percentSamplesFromTypeCover7 = 0.0353
    nbrIdxsFromTypeCover1 = numpy.floor(percentSamplesFromTypeCover1*nbr_testing_samples)
    nbrIdxsFromTypeCover2 = numpy.floor(percentSamplesFromTypeCover2*nbr_testing_samples)
    nbrIdxsFromTypeCover3 = numpy.floor(percentSamplesFromTypeCover3*nbr_testing_samples)
    nbrIdxsFromTypeCover4 = numpy.floor(percentSamplesFromTypeCover4*nbr_testing_samples)
    nbrIdxsFromTypeCover5 = numpy.floor(percentSamplesFromTypeCover5*nbr_testing_samples)
    nbrIdxsFromTypeCover6 = numpy.floor(percentSamplesFromTypeCover6*nbr_testing_samples)
    nbrIdxsFromTypeCover7 = numpy.floor(percentSamplesFromTypeCover7*nbr_testing_samples)
    total = nbrIdxsFromTypeCover1+nbrIdxsFromTypeCover2+nbrIdxsFromTypeCover3+nbrIdxsFromTypeCover4+nbrIdxsFromTypeCover5+nbrIdxsFromTypeCover6+nbrIdxsFromTypeCover7
    
    while(total < nbr_testing_samples):
        num = numpy.random.randint(1,7)
        if(num == 1):
            nbrIdxsFromTypeCover1 = nbrIdxsFromTypeCover1 + 1
        elif(num == 2):
            nbrIdxsFromTypeCover2 = nbrIdxsFromTypeCover2 + 1
        elif(num == 3):
            nbrIdxsFromTypeCover3 = nbrIdxsFromTypeCover3 + 1
        elif(num == 4):
            nbrIdxsFromTypeCover4 = nbrIdxsFromTypeCover4 + 1
        elif(num == 5):
            nbrIdxsFromTypeCover5 = nbrIdxsFromTypeCover5 + 1
        elif(num == 6):
            nbrIdxsFromTypeCover6 = nbrIdxsFromTypeCover6 + 1
        elif(num == 7):
            nbrIdxsFromTypeCover7 = nbrIdxsFromTypeCover7 + 1
        total = total + 1

    return [nbrIdxsFromTypeCover1, nbrIdxsFromTypeCover2, nbrIdxsFromTypeCover3, nbrIdxsFromTypeCover4, nbrIdxsFromTypeCover5, nbrIdxsFromTypeCover6, nbrIdxsFromTypeCover7]
    

def getNbrTrainingIndexes(nbr_training_samples):
    
    nbrIdxsFromTypeCover1 = nbr_training_samples/7
    nbrIdxsFromTypeCover2 = nbr_training_samples/7
    nbrIdxsFromTypeCover3 = nbr_training_samples/7
    nbrIdxsFromTypeCover4 = nbr_training_samples/7
    nbrIdxsFromTypeCover5 = nbr_training_samples/7
    nbrIdxsFromTypeCover6 = nbr_training_samples/7
    nbrIdxsFromTypeCover7 = nbr_training_samples/7
    total = nbrIdxsFromTypeCover1+nbrIdxsFromTypeCover2+nbrIdxsFromTypeCover3+nbrIdxsFromTypeCover4+nbrIdxsFromTypeCover5+nbrIdxsFromTypeCover6+nbrIdxsFromTypeCover7
    
    while(total < nbr_training_samples):
        num = numpy.random.randint(1,7)
        if(num == 1):
            nbrIdxsFromTypeCover1 = nbrIdxsFromTypeCover1 + 1
        elif(num == 2):
            nbrIdxsFromTypeCover2 = nbrIdxsFromTypeCover2 + 1
        elif(num == 3):
            nbrIdxsFromTypeCover3 = nbrIdxsFromTypeCover3 + 1
        elif(num == 4):
            nbrIdxsFromTypeCover4 = nbrIdxsFromTypeCover4 + 1
        elif(num == 5):
            nbrIdxsFromTypeCover5 = nbrIdxsFromTypeCover5 + 1
        elif(num == 6):
            nbrIdxsFromTypeCover6 = nbrIdxsFromTypeCover6 + 1
        elif(num == 7):
            nbrIdxsFromTypeCover7 = nbrIdxsFromTypeCover7 + 1
        total = total + 1

    return [nbrIdxsFromTypeCover1, nbrIdxsFromTypeCover2, nbrIdxsFromTypeCover3, nbrIdxsFromTypeCover4, nbrIdxsFromTypeCover5, nbrIdxsFromTypeCover6, nbrIdxsFromTypeCover7]
    
def getTrainingSet(dataSet, nbr_training_samples):
    
    [nbrIdxsFrmTypeCover1, nbrIdxsFrmTypeCover2, nbrIdxsFrmTypeCover3, nbrIdxsFrmTypeCover4, nbrIdxsFrmTypeCover5, nbrIdxsFrmTypeCover6, nbrIdxsFrmTypeCover7] = getNbrTrainingIndexes(nbr_training_samples)
    [typecover1_dataSet, typecover2_dataSet, typecover3_dataSet, typecover4_dataSet, typecover5_dataSet, typecover6_dataSet, typecover7_dataSet] = sortData(dataSet)
    
    indexesTypeCover1Array = []
    indexesTypeCover2Array = []
    indexesTypeCover3Array = []
    indexesTypeCover4Array = []
    indexesTypeCover5Array = []
    indexesTypeCover6Array = []
    indexesTypeCover7Array = []
    
    for i in range(0, nbr_training_samples-1):
        if(nbrIdxsFrmTypeCover1-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            while(idx in indexesTypeCover1Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            indexesTypeCover1Array.append(idx)
        if(nbrIdxsFrmTypeCover2-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover1)
            while(idx in indexesTypeCover2Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover2)
            indexesTypeCover2Array.append(idx)
        if(nbrIdxsFrmTypeCover3-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover3)
            while(idx in indexesTypeCover3Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover3)
            indexesTypeCover3Array.append(idx)
        if(nbrIdxsFrmTypeCover4-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover4)
            while(idx in indexesTypeCover4Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover4)
            indexesTypeCover4Array.append(idx)  
        if(nbrIdxsFrmTypeCover5-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover5)
            while(idx in indexesTypeCover5Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover5)
            indexesTypeCover5Array.append(idx) 
        if(nbrIdxsFrmTypeCover6-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover6)
            while(idx in indexesTypeCover6Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover6)
            indexesTypeCover6Array.append(idx)  
        if(nbrIdxsFrmTypeCover7-1 >= i):
            idx = numpy.random.randint(0, nbrIdxsFrmTypeCover7)
            while(idx in indexesTypeCover7Array):
                idx = numpy.random.randint(0, nbrIdxsFrmTypeCover7)
            indexesTypeCover7Array.append(idx)
    
    X_train_TypeCover1 = numpy.array(typecover1_dataSet)[indexesTypeCover1Array,0:53]
    X_train_TypeCover2 = numpy.array(typecover2_dataSet)[indexesTypeCover2Array,0:53]
    X_train_TypeCover3 = numpy.array(typecover3_dataSet)[indexesTypeCover3Array,0:53]
    X_train_TypeCover4 = numpy.array(typecover4_dataSet)[indexesTypeCover4Array,0:53]
    X_train_TypeCover5 = numpy.array(typecover5_dataSet)[indexesTypeCover5Array,0:53]
    X_train_TypeCover6 = numpy.array(typecover6_dataSet)[indexesTypeCover6Array,0:53]
    X_train_TypeCover7 = numpy.array(typecover7_dataSet)[indexesTypeCover7Array,0:53]

    Y_test_TypeCover1 = numpy.array(typecover1_dataSet)[indexesTypeCover1Array,55:61]
    Y_test_TypeCover2 = numpy.array(typecover2_dataSet)[indexesTypeCover2Array,55:61]
    Y_test_TypeCover3 = numpy.array(typecover3_dataSet)[indexesTypeCover3Array,55:61]
    Y_test_TypeCover4 = numpy.array(typecover4_dataSet)[indexesTypeCover5Array,55:61]
    Y_test_TypeCover5 = numpy.array(typecover5_dataSet)[indexesTypeCover5Array,55:61]
    Y_test_TypeCover6 = numpy.array(typecover6_dataSet)[indexesTypeCover6Array,55:61]
    Y_test_TypeCover7 = numpy.array(typecover7_dataSet)[indexesTypeCover7Array,55:61]
    Y_train = numpy.concatenate((Y_test_TypeCover1, Y_test_TypeCover2, Y_test_TypeCover3, Y_test_TypeCover4, Y_test_TypeCover5, Y_test_TypeCover6, Y_test_TypeCover7), axis=0)
    indexes = [indexesTypeCover1Array, indexesTypeCover2Array, indexesTypeCover3Array, indexesTypeCover4Array, indexesTypeCover5Array, indexesTypeCover6Array, indexesTypeCover7Array]
    
    return [X_train, Y_train, indexes]


def getTestSet(dataSet, training_indexes, nbr_testing_samples, use_all):
    
    [nbrIdxsFrmTypeCover1, nbrIdxsFrmTypeCover2, nbrIdxsFrmTypeCover3, nbrIdxsFrmTypeCover4, nbrIdxsFrmTypeCover5, nbrIdxsFrmTypeCover6, nbrIdxsFrmTypeCover7] = getNbrTestingIndexes(nbr_testing_samples)

    typecover1_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 1)]
    typecover2_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 2)]
    typecover3_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 3)]
    typecover4_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 4)]
    typecover5_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 5)]
    typecover6_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 6)]
    typecover7_dataSet = dataSet[numpy.ix_(dataSet[:,54] == 7)]
    
    indexesTypeCover1Array = []
    indexesTypeCover2Array = []
    indexesTypeCover3Array = []
    indexesTypeCover4Array = []
    indexesTypeCover5Array = []
    indexesTypeCover6Array = []
    indexesTypeCover7Array = []
    
    for i in range(1, len(training_indexes)+1):
        if(i == 1):
            indexesTypeCover1Array = training_indexes[i-1]
        elif(i == 2):
            indexesTypeCover2Array = training_indexes[i-1]
        elif(i == 3):
            indexesTypeCover3Array = training_indexes[i-1]
        elif(i == 4):
            indexesTypeCover4Array = training_indexes[i-1]
        elif(i == 5):
            indexesTypeCover5Array = training_indexes[i-1]
        elif(i == 6):
            indexesTypeCover6Array = training_indexes[i-1]
        elif(i == 7):
            indexesTypeCover7Array = training_indexes[i-1]

    typecover1_dataSet = numpy.delete(typecover1_dataSet, indexesTypeCover1Array, axis=0)
    typecover2_dataSet = numpy.delete(typecover2_dataSet, indexesTypeCover2Array, axis=0)
    typecover3_dataSet = numpy.delete(typecover3_dataSet, indexesTypeCover3Array, axis=0)
    typecover4_dataSet = numpy.delete(typecover4_dataSet, indexesTypeCover4Array, axis=0)
    typecover5_dataSet = numpy.delete(typecover5_dataSet, indexesTypeCover5Array, axis=0)
    typecover6_dataSet = numpy.delete(typecover6_dataSet, indexesTypeCover6Array, axis=0)
    typecover7_dataSet = numpy.delete(typecover7_dataSet, indexesTypeCover7Array, axis=0)    

    
    if (use_all == True):
        X_typecover1_dataSet =  numpy.array(typecover1_dataSet)[:,0:53]
        X_typecover2_dataSet =  numpy.array(typecover2_dataSet)[:,0:53]
        X_typecover3_dataSet =  numpy.array(typecover3_dataSet)[:,0:53]
        X_typecover4_dataSet =  numpy.array(typecover4_dataSet)[:,0:53]
        X_typecover5_dataSet =  numpy.array(typecover5_dataSet)[:,0:53]
        X_typecover6_dataSet =  numpy.array(typecover6_dataSet)[:,0:53]
        X_typecover7_dataSet =  numpy.array(typecover7_dataSet)[:,0:53]
        X_test = numpy.concatenate((X_typecover1_dataSet, X_typecover2_dataSet, X_typecover3_dataSet, X_typecover4_dataSet, X_typecover5_dataSet, X_typecover6_dataSet, X_typecover7_dataSet), axis=0)

        Y_typecover1_dataSet =  numpy.array(typecover1_dataSet)[:,55:61]
        Y_typecover2_dataSet =  numpy.array(typecover2_dataSet)[:,55:61]
        Y_typecover3_dataSet =  numpy.array(typecover3_dataSet)[:,55:61]
        Y_typecover4_dataSet =  numpy.array(typecover4_dataSet)[:,55:61]
        Y_typecover5_dataSet =  numpy.array(typecover5_dataSet)[:,55:61]
        Y_typecover6_dataSet =  numpy.array(typecover6_dataSet)[:,55:61]
        Y_typecover7_dataSet =  numpy.array(typecover7_dataSet)[:,55:61]
        Y_test = numpy.concatenate((Y_typecover1_dataSet, Y_typecover2_dataSet, Y_typecover3_dataSet, Y_typecover4_dataSet, Y_typecover5_dataSet, Y_typecover6_dataSet, Y_typecover7_dataSet), axis=0)
    return [X_test, Y_test]

class LossHistory(cb.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        batch_loss = logs.get('loss')
        self.losses.append(batch_loss)

def init_model():
    model = Sequential()
    model.add(Dense(1028, input_dim=53, activation='relu', activity_regularizer=regularizers.l2(0.00001)))
    model.add(Dropout(0.25))
    model.add(Dense(512, activation='relu', activity_regularizer=regularizers.l2(0.00001)))
    model.add(Dropout(0.25))
    model.add(Dense(216, activation='relu', activity_regularizer=regularizers.l2(0.00001)))
    model.add(Dropout(0.25))
    model.add(Dense(6, activation='softmax', activity_regularizer=regularizers.l2(0.00001)))

    model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False),
              metrics=['accuracy'])
    return model

def plot_losses(losses):
    plt.plot(losses)
    plt.title('Loss per batch')
    plt.show()
    
filePathTrain = 'C:/Users/computer/Desktop/normalized.csv' 

dataSet = numpy.loadtxt(filePathTrain, delimiter=",")
#X_train = dataSet[0:3780,0:53]
#Y_train = dataSet[0:3780,55:61]
#X_test = dataSet[3000:3780,0:53]
#Y_test = dataSet[3000:3780,55:61]
[X_train, Y_train, indexes] =  getTrainingSet(dataSet, 11340)
[X_test, Y_test] =  getTestSet(dataSet, indexes, 569672, True)

print('X Training:' + str(X_train.shape))
print('Y Training:' + str(Y_train.shape))
print('X Testing:' + str(X_test.shape))
print('Y Testing:' + str(Y_test.shape))

model = init_model()
history = LossHistory()
model.fit(X_train, Y_train, epochs=2000, batch_size=512, callbacks=[history])
print("")
print("Training Set Results:")
score = model.evaluate(X_train, Y_train)
print(score)
print("")

print("")
print("Testing Set Results:")
score = model.evaluate(X_test, Y_test)
print(score)
print("")

plot_losses(history.losses)
# Out:
# X Training:(11340, 53)
# Y Training:(11340, 6)
# X Testing:(569672, 53)
# Y Testing:(569672, 6)
# Epoch 1/2000
# 11340/11340 [==============================] - 3s 267us/step - loss: 1.1521 - acc: 0.6078
# Epoch 2/2000
# 11340/11340 [==============================] - 0s 19us/step - loss: 0.8023 - acc: 0.7247
# Epoch 3/2000
# 11340/11340 [==============================] - 0s 18us/step - loss: 0.6951 - acc: 0.7631
# Epoch 4/2000
# 11340/11340 [==============================] - 0s 18us/step - loss: 0.6426 - acc: 0.7779
# Epoch 5/2000
# 11340/11340 [==============================] - 0s 19us/step - loss: 0.6035 - acc: 0.7848
# Epoch 6/2000
# 11340/11340 [==============================] - 0s 18us/step - loss: 0.5723 - acc: 0.8013
# Epoch 7/2000
# 11340/11340 [==============================] - 0s 20us/step - loss: 0.5426 - acc: 0.8123
# Epoch 8/2000
# 11340/11340 [==============================] - 0s 23us/step - loss: 0.5176 - acc: 0.8173
# Epoch 9/2000
# ...
